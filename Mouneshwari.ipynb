# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("sales_data.csv")
df.head()
# Out:
#    Order_ID  Order_Date  Year     Month       City         Category  \
# 0      1001  2023-01-05  2023   January  Bangalore       Technology
# 1      1002  2023-01-07  2023   January  Hyderabad        Furniture
# 2      1003  2023-01-10  2023   January     Mumbai       Technology
# 3      1004  2023-02-02  2023  February      Delhi  Office Supplies
# 4      1005  2023-02-10  2023  February  Bangalore        Furniture
#
#          Product  Quantity  Unit_Price  Total_Sales  Profit
# 0         Laptop         2       60000       120000   20000
# 1          Chair         5        3000        15000    3000
# 2         Mobile         3       20000        60000   10000
# 3  Printer Paper        10         500         5000    1200
# 4          Table         2       10000        20000    4000

# %%
df.shape
# Out:
# (15, 11)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Year', 'Month', 'City', 'Category',
#        'Product', 'Quantity', 'Unit_Price', 'Total_Sales', 'Profit'],
#       dtype='str')

# %%
df.describe()
# Out:
#           Order_ID    Year   Quantity    Unit_Price    Total_Sales  \
# count    15.000000    15.0  15.000000     15.000000      15.000000
# mean   1008.000000  2023.0   7.200000  15736.666667   29600.000000
# std       4.472136     0.0  12.439568  20065.717625   31717.615655
# min    1001.000000  2023.0   1.000000     50.000000    2500.000000
# 25%    1004.500000  2023.0   2.000000   2000.000000    8500.000000
# 50%    1008.000000  2023.0   3.000000  10000.000000   15000.000000
# 75%    1011.500000  2023.0   5.500000  20000.000000   42500.000000
# max    1015.000000  2023.0  50.000000  60000.000000  120000.000000
#
#              Profit
# count     15.000000
# mean    5453.333333
# std     5208.079803
# min      800.000000
# 25%     1900.000000
# 50%     3000.000000
# 75%     8000.000000
# max    20000.000000

# %%
total_sales = df["Total_Sales"].sum()
total_profit = df["Profit"].sum()

print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
# Out:
# Total Sales: 444000
# Total Profit: 81800

# %%
monthly_sales = df.groupby("Month")["Total_Sales"].sum()
monthly_sales
# Out:
# Month
# April        75000
# February     25000
# January     195000
# July         22000
# June         49000
# March        15500
# May          62500
# Name: Total_Sales, dtype: int64

# %%
monthly_sales.plot(kind="bar")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
city_sales = df.groupby("City")["Total_Sales"].sum()
city_sales
# Out:
# City
# Bangalore    142500
# Chennai       78000
# Delhi         47000
# Hyderabad    100000
# Mumbai        76500
# Name: Total_Sales, dtype: int64

# %%
city_sales.plot(kind="bar")
plt.title("Sales by City")
plt.xlabel("City")
plt.ylabel("Total Sales")
plt.show()

# %%
category_sales = df.groupby("Category")["Total_Sales"].sum()
category_sales
# Out:
# Category
# Furniture           84000
# Office Supplies     27000
# Technology         333000
# Name: Total_Sales, dtype: int64

# %%
category_sales.plot(kind="bar")
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
product_profit = df.groupby("Product")["Profit"].sum()
product_profit.sort_values(ascending=False)
# Out:
# Product
# Laptop           30000
# Mobile           17000
# Tablet            9000
# Sofa              7000
# Table             6000
# Chair             4800
# Printer Ink       2500
# Notebook          2000
# Headphones        1500
# Printer Paper     1200
# Pen                800
# Name: Profit, dtype: int64

# %%
profit_margin = (df["Profit"].sum() / df["Total_Sales"].sum()) * 100
print("Overall Profit Margin: ", round(profit_margin, 2), "%")
# Out:
# Overall Profit Margin:  18.42 %
